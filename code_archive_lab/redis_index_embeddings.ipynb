# %%
import openai

from typing import List, Iterator
import pandas as pd
import numpy as np
import os
import pickle
from ast import literal_eval

# Redis client library for Python
import redis
from redis.commands.search.indexDefinition import (
    IndexDefinition,
    IndexType
)
from redis.commands.search.query import Query
from redis.commands.search.field import (
    TextField,
    VectorField
)

# I've set this to our new embeddings model, this can be changed to the embedding model of your choice
EMBEDDING_MODEL = "text-embedding-3-small"

# Ignore unclosed SSL socket warnings - optional in case you get these errors
import warnings

warnings.filterwarnings(action="ignore", message="unclosed", category=ResourceWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# #### Load Data

# %%
transcript_df = pd.read_csv('data/embeddings.csv')

# %%
transcript_df.head()
# Out:
#    vector_id  id    video_key            chunk_key  \
# 0          0   0  4b6bwcWK6GE  4b6bwcWK6GE_chunk_0
# 1          1   1  H-XfCl-HpRM  H-XfCl-HpRM_chunk_0
# 2          2   1  H-XfCl-HpRM  H-XfCl-HpRM_chunk_1
# 3          3   1  H-XfCl-HpRM  H-XfCl-HpRM_chunk_2
# 4          4   1  H-XfCl-HpRM  H-XfCl-HpRM_chunk_3
#
#                                       content_vector  \
# 0  [0.007484582718461752, -0.0047697206027805805,...
# 1  [0.0029184420127421618, -0.010121479630470276,...
# 2  [0.0036486308090388775, -0.019859155640006065,...
# 3  [-0.008053109981119633, -0.040147699415683746,...
# 4  [0.02524896338582039, 0.006082533393055201, -0...
#
#                                         title_vector
# 0  [-0.027406472712755203, -0.012386651709675789,...
# 1  [-0.02722085453569889, 0.0020761173218488693, ...
# 2  [-0.02722085453569889, 0.0020761173218488693, ...
# 3  [-0.02722085453569889, 0.0020761173218488693, ...
# 4  [-0.02722085453569889, 0.0020761173218488693, ...

# %%
# Load title dictionary from pickle file
with open('data/title_dict.pkl', 'rb') as f:
    title_dict = pickle.load(f)

title_df = pd.DataFrame(title_dict.items(), columns=['video_key', 'title'])
title_df.head()
# Out:
#      video_key                                              title
# 0  4b6bwcWK6GE                Welcome to the Huberman Lab Podcast
# 1  H-XfCl-HpRM                     How Your Brain Works & Changes
# 2  nm1TxQj9IsQ       Master Your Sleep & Be More Alert When Awake
# 3  nwSkFq4tyC0  Using Science to Optimize Sleep, Learning & Me...
# 4  NAATB55oxeQ  How to Defeat Jet Lag, Shift Work & Sleeplessness

# %%
# Load title dictionary from pickle file
with open('data/chunk_dict.pkl', 'rb') as f:
    chunk_dict = pickle.load(f)

chunk_df = pd.DataFrame(chunk_dict.items(), columns=['chunk_key', 'text'])
chunk_df.head()
# Out:
#              chunk_key                                               text
# 0  4b6bwcWK6GE_chunk_0  - Welcome to the Huberman Lab Podcast\nwhere w...
# 1  H-XfCl-HpRM_chunk_0  - Welcome to the Huberman Lab Podcast\nwhere w...
# 2  H-XfCl-HpRM_chunk_1  which is more a measure\nof your biological ag...
# 3  H-XfCl-HpRM_chunk_2  If I play the keys on a\npiano in a particular...
# 4  H-XfCl-HpRM_chunk_3  We come into the world and\nour brain has a ki...

# %%
# Join transcript_df with title_df on video_id to add titles
transcript_df = transcript_df.merge(title_df, on='video_key', how='left')
transcript_df = transcript_df.merge(chunk_df, on='chunk_key', how='left')
transcript_df.head()
# Out:
#    vector_id  id    video_key            chunk_key  \
# 0          0   0  4b6bwcWK6GE  4b6bwcWK6GE_chunk_0
# 1          1   1  H-XfCl-HpRM  H-XfCl-HpRM_chunk_0
# 2          2   1  H-XfCl-HpRM  H-XfCl-HpRM_chunk_1
# 3          3   1  H-XfCl-HpRM  H-XfCl-HpRM_chunk_2
# 4          4   1  H-XfCl-HpRM  H-XfCl-HpRM_chunk_3
#
#                                       content_vector  \
# 0  [0.007484582718461752, -0.0047697206027805805,...
# 1  [0.0029184420127421618, -0.010121479630470276,...
# 2  [0.0036486308090388775, -0.019859155640006065,...
# 3  [-0.008053109981119633, -0.040147699415683746,...
# 4  [0.02524896338582039, 0.006082533393055201, -0...
#
#                                         title_vector  \
# 0  [-0.027406472712755203, -0.012386651709675789,...
# 1  [-0.02722085453569889, 0.0020761173218488693, ...
# 2  [-0.02722085453569889, 0.0020761173218488693, ...
# 3  [-0.02722085453569889, 0.0020761173218488693, ...
# 4  [-0.02722085453569889, 0.0020761173218488693, ...
#
#                                  title  \
# 0  Welcome to the Huberman Lab Podcast
# 1       How Your Brain Works & Changes
# 2       How Your Brain Works & Changes
# 3       How Your Brain Works & Changes
# 4       How Your Brain Works & Changes
#
#                                                 text
# 0  - Welcome to the Huberman Lab Podcast\nwhere w...
# 1  - Welcome to the Huberman Lab Podcast\nwhere w...
# 2  which is more a measure\nof your biological ag...
# 3  If I play the keys on a\npiano in a particular...
# 4  We come into the world and\nour brain has a ki...

# %%
# Read vectors from strings back into a list
transcript_df['title_vector'] = transcript_df.title_vector.apply(literal_eval)
transcript_df['content_vector'] = transcript_df.content_vector.apply(literal_eval)

# Set vector_id to be a string
transcript_df['video_key'] = transcript_df['video_key'].apply(str)

# %%
transcript_df
# Out:
#       vector_id   id    video_key             chunk_key  \
# 0             0    0  4b6bwcWK6GE   4b6bwcWK6GE_chunk_0
# 1             1    1  H-XfCl-HpRM   H-XfCl-HpRM_chunk_0
# 2             2    1  H-XfCl-HpRM   H-XfCl-HpRM_chunk_1
# 3             3    1  H-XfCl-HpRM   H-XfCl-HpRM_chunk_2
# 4             4    1  H-XfCl-HpRM   H-XfCl-HpRM_chunk_3
# ...         ...  ...          ...                   ...
# 8276       8276  296  SsKkZTjUJEk  SsKkZTjUJEk_chunk_41
# 8277       8277  296  SsKkZTjUJEk  SsKkZTjUJEk_chunk_42
# 8278       8278  296  SsKkZTjUJEk  SsKkZTjUJEk_chunk_43
# 8279       8279  296  SsKkZTjUJEk  SsKkZTjUJEk_chunk_44
# 8280       8280  296  SsKkZTjUJEk  SsKkZTjUJEk_chunk_45
#
#                                          content_vector  \
# 0     [0.007484582718461752, -0.0047697206027805805,...
# 1     [0.0029184420127421618, -0.010121479630470276,...
# 2     [0.0036486308090388775, -0.019859155640006065,...
# 3     [-0.008053109981119633, -0.040147699415683746,...
# 4     [0.02524896338582039, 0.006082533393055201, -0...
# ...                                                 ...
# 8276  [0.03004799596965313, 0.04273688793182373, -0....
# 8277  [0.028704863041639328, -0.013342558406293392, ...
# 8278  [0.025788744911551476, -0.03260801360011101, -...
# 8279  [0.012146520428359509, -0.00024650024715811014...
# 8280  [0.0017148900078609586, 0.019638169556856155, ...
#
#                                            title_vector  \
# 0     [-0.027406472712755203, -0.012386651709675789,...
# 1     [-0.02722085453569889, 0.0020761173218488693, ...
# 2     [-0.02722085453569889, 0.0020761173218488693, ...
# 3     [-0.02722085453569889, 0.0020761173218488693, ...
# 4     [-0.02722085453569889, 0.0020761173218488693, ...
# ...                                                 ...
# 8276  [-0.001950831268914044, 0.027140211313962936, ...
# 8277  [-0.001950831268914044, 0.027140211313962936, ...
# 8278  [-0.001950831268914044, 0.027140211313962936, ...
# 8279  [-0.001950831268914044, 0.027140211313962936, ...
# 8280  [-0.001950831268914044, 0.027140211313962936, ...
#
#                                                   title  \
# 0                   Welcome to the Huberman Lab Podcast
# 1                        How Your Brain Works & Changes
# 2                        How Your Brain Works & Changes
# 3                        How Your Brain Works & Changes
# 4                        How Your Brain Works & Changes
# ...                                                 ...
# 8276  How to Grow From Doing Hard Things | Michael E...
# 8277  How to Grow From Doing Hard Things | Michael E...
# 8278  How to Grow From Doing Hard Things | Michael E...
# 8279  How to Grow From Doing Hard Things | Michael E...
# 8280  How to Grow From Doing Hard Things | Michael E...
#
#                                                    text
# 0     - Welcome to the Huberman Lab Podcast\nwhere w...
# 1     - Welcome to the Huberman Lab Podcast\nwhere w...
# 2     which is more a measure\nof your biological ag...
# 3     If I play the keys on a\npiano in a particular...
# 4     We come into the world and\nour brain has a ki...
# ...                                                 ...
# 8276  low. We gamble like once a month. I\nmean, we'...
# 8277  just gonna end up in a pit. Yeah,\ntotally. Yo...
# 8278  of the issues is we face is that a lot\nof thi...
# 8279  went places I didn't anticipate. And as\nalway...
# 8280  three-page PDFs that cover everything\nfrom ho...
#
# [8281 rows x 8 columns]

# %%
transcript_df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8281 entries, 0 to 8280
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   vector_id       8281 non-null   int64
#  1   id              8281 non-null   int64
#  2   video_key       8281 non-null   object
#  3   chunk_key       8281 non-null   object
#  4   content_vector  8281 non-null   object
#  5   title_vector    8281 non-null   object
#  6   title           8281 non-null   object
#  7   text            8281 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 517.7+ KB

# %% [markdown]
# ### Redis

# %% [markdown]
# #### Setup

# %%
REDIS_HOST =  "localhost"
REDIS_PORT = 6379
REDIS_PASSWORD = "" # default for passwordless Redis

# Connect to Redis
redis_client = redis.Redis(
    host=REDIS_HOST,
    port=REDIS_PORT,
    password=REDIS_PASSWORD
)
redis_client.ping()
# Out:
# True

# %% [markdown]
# #### Creating a Search Index
#
# The below cells will show how to specify and create a search index in Redis. We will
#
# 1. Set some constants for defining our index like the distance metric and the index name
# 2. Define the index schema with RediSearch fields
# 3. Create the index

# %%
# Constants
VECTOR_DIM = len(transcript_df['title_vector'][0]) # length of the vectors
VECTOR_NUMBER = len(transcript_df)                 # initial number of vectors
INDEX_NAME = "embeddings-index"                    # name of the search index
PREFIX = "doc"                                     # prefix for the document keys
DISTANCE_METRIC = "COSINE"                         # distance metric for the vectors (ex. COSINE, IP, L2)

# %%
# Define RediSearch fields for each of the columns in the dataset
title = TextField(name="title")
text = TextField(name="text")
video_key = TextField(name="video_key")
chunk_key = TextField(name="chunk_key")
# url = TextField(name="url")

title_embedding = VectorField("title_vector",
    "FLAT", {
        "TYPE": "FLOAT32",
        "DIM": VECTOR_DIM,
        "DISTANCE_METRIC": DISTANCE_METRIC,
        "INITIAL_CAP": VECTOR_NUMBER,
    }
)
text_embedding = VectorField("content_vector",
    "FLAT", {
        "TYPE": "FLOAT32",
        "DIM": VECTOR_DIM,
        "DISTANCE_METRIC": DISTANCE_METRIC,
        "INITIAL_CAP": VECTOR_NUMBER,
    }
)
fields = [title, text, video_key, chunk_key, title_embedding, text_embedding]

# %%
# Check if index exists
try:
    redis_client.ft(INDEX_NAME).info()
    print("Index already exists")
except:
    # Create RediSearch Index
    redis_client.ft(INDEX_NAME).create_index(
        fields = fields,
        definition = IndexDefinition(prefix=[PREFIX], index_type=IndexType.HASH)
    )

# %% [markdown]
# #### Load Documents into Index

# %%
def index_documents(client: redis.Redis, prefix: str, documents: pd.DataFrame):
    records = documents.to_dict("records")
    for doc in records:
        key = f"{prefix}:{str(doc['id'])}"

        # create byte vectors for title and content
        title_embedding = np.array(doc["title_vector"], dtype=np.float32).tobytes()
        content_embedding = np.array(doc["content_vector"], dtype=np.float32).tobytes()

        # replace list of floats with byte vectors
        doc["title_vector"] = title_embedding
        doc["content_vector"] = content_embedding

        client.hset(key, mapping = doc)

# %%
index_documents(redis_client, PREFIX, transcript_df)
print(f"Loaded {redis_client.info()['db0']['keys']} documents in Redis search index with name: {INDEX_NAME}")
# Out:
# Loaded 297 documents in Redis search index with name: embeddings-index

# %% [markdown]
# #### Running Search Queries

# %%
def search_redis(
    openai_client: openai.OpenAI,
    redis_client: redis.Redis,
    user_query: str,
    index_name: str = "embeddings-index",
    vector_field: str = "title_vector",
    return_fields: list = ["title", "text", "chunk_key", "vector_score"],
    hybrid_fields = "*",
    k: int = 10,
) -> List[dict]:

    # Creates embedding vector from user query
    embedded_query = openai_client.embeddings.create(input=user_query,
                                            model=EMBEDDING_MODEL,
                                            ).data[0].embedding

    # Prepare the Query
    base_query = f'{hybrid_fields}=>[KNN {k} @{vector_field} $vector AS vector_score]'
    query = (
        Query(base_query)
         .return_fields(*return_fields)
         .sort_by("vector_score")
         .paging(0, k)
         .dialect(2)
    )
    params_dict = {"vector": np.array(embedded_query).astype(dtype=np.float32).tobytes()}

    # perform vector search
    results = redis_client.ft(index_name).search(query, params_dict)
    for i, article in enumerate(results.docs):
        score = 1 - float(article.vector_score)
        print(f"{i}. {article.title}\n(Score: {round(score ,3) })")
    return results.docs

# %%
# For using OpenAI to generate query embedding
from dotenv import load_dotenv
load_dotenv()
open_api_key = os.getenv("OPENAI_API_KEY")
openai_client = openai.OpenAI(api_key=open_api_key)

# %%
results = search_redis(
    openai_client, 
    redis_client, 
    'dopamine in the brain', 
    k=10
)
# Out:
# 0. Controlling Your Dopamine For Motivation, Focus & Satisfaction
# (Score: 0.48)
# 1. Time Perception & Entrainment by Dopamine, Serotonin & Hormones
# (Score: 0.428)
# 2. How Your Brainâs Reward Circuits Drive Your Choices | Dr. Robert Malenka
# (Score: 0.4)
# 3. Leverage Dopamine to Overcome Procrastination & Optimize Effort | Huberman Lab Podcast
# (Score: 0.377)
# 4. How Relationships Shape Your Brain | Dr. Allan Schore
# (Score: 0.346)
# 5. Control Pain & Heal Faster With Your Brain | Huberman Lab Essentials
# (Score: 0.342)
# 6. Psychedelics & Neurostimulation for Brain Rewiring | Dr. Nolan Williams
# (Score: 0.334)
# 7. How Your Brain Works & Changes
# (Score: 0.334)
# 8. Using Play to Rewire & Improve Your Brain
# (Score: 0.332)
# 9. Essentials: How Your Brain Works & Changes
# (Score: 0.332)

# %%
results[0].text
# Out:
# "www.T-H-O-R-N-E.com/u/huberman.\nAnd there, you can see what I take.\nYou can get 20% off any\nof those supplements.\nAnd if you navigate into the Thorne site\nthrough that portal,\nthen you can get 20% off\nany of the supplements\nthat Thorne makes.\nIf you're not already\nfollowing us on Instagram\nat Huberman Lab, please do so.\nThere I teach neuroscience\ntools and information.\nOftentimes, it's tools and information\nthat I don't cover on the podcast.\nWe're also on Twitter,\nalso at Huberman Lab.\nAnd last but certainly not least,\nthank you for your interest in science.\n[energetic music]"

# %%
results = search_redis(
    openai_client, 
    redis_client, 
    'Sleep and Exercise', 
    vector_field='content_vector', 
    k=10
)
# Out:
# 0. How to Defeat Jet Lag, Shift Work & Sleeplessness | Huberman Lab Essentials
# (Score: 0.494)
# 1. Understand and Use Dreams to Learn and Forget | Huberman Lab Essentials
# (Score: 0.481)
# 2. Maximize Productivity, Physical & Mental Health With Daily Tools | Huberman Lab Essentials
# (Score: 0.47)
# 3. The Science & Practice of Perfecting Your Sleep | Huberman Lab Essentials
# (Score: 0.459)
# 4. Dr. Matt Walker: The Biology of Sleep & Your Unique Sleep Needs | Huberman Lab Guest Series
# (Score: 0.431)
# 5. Optimize Your Learning & Creativity With Science-Based Tools | Huberman Lab Essentials
# (Score: 0.426)
# 6. Use Sleep to Enhance Learning, Memory & Emotional State | Dr. Gina Poe
# (Score: 0.416)
# 7. How to Heal From Post-Traumatic Stress Disorder (PTSD) | Dr. Victor CarriÃ³n
# (Score: 0.41)
# 8. Dr. Matt Walker: Improve Sleep to Boost Mood & Emotional Regulation | Huberman Lab Guest Series
# (Score: 0.409)
# 9. Create Your Ideal Future Using Science-Based Protocols | Ari Wallach
# (Score: 0.407)

# %% [markdown]
# #### Hybrid Queries with Redis

# %%
def create_hybrid_field(field_name: str, value: str) -> str:
    return f'@{field_name}:"{value}"'

# %%
# search the content vector for articles about famous battles in Scottish history and only include results with Scottish in the title
results = search_redis(openai_client,
                       redis_client,
                       "Sleep and Exercise",
                       vector_field="title_vector",
                       k=5,
                       hybrid_fields=create_hybrid_field("title", "Huberman")
                       )
# Out:
# 0. Using Science to Optimize Sleep, Learning & Metabolism | Huberman Lab Essentials
# (Score: 0.521)
# 1. The Science & Practice of Perfecting Your Sleep | Huberman Lab Essentials
# (Score: 0.499)
# 2. How to Defeat Jet Lag, Shift Work & Sleeplessness | Huberman Lab Essentials
# (Score: 0.488)
# 3. Dr. Matt Walker: Protocols to Improve Your Sleep | Huberman Lab Guest Series
# (Score: 0.47)
# 4. Sleep Toolkit: Tools for Optimizing Sleep & Sleep-Wake Timing | Huberman Lab Podcast #84
# (Score: 0.461)

# %%
# run a hybrid query for articles about Art in the title vector and only include results with the phrase "Leonardo da Vinci" in the text
results = search_redis(openai_client,
                       redis_client,
                       "Sleep and Exercise",
                       vector_field="title_vector",
                       k=5,
                       hybrid_fields=create_hybrid_field("text", "Huberman")
                       )
# find specific mention of Leonardo da Vinci in the text that our full-text-search query returned
mention = [sentence for sentence in results[0].text.split("\n") if "Huberman" in sentence][0]
mention
# Out:
# 0. Timing Light, Food, & Exercise for Better Sleep, Energy & Mood | Dr. Samer Hattar
# (Score: 0.534)
# 1. Master Your Sleep & Be More Alert When Awake
# (Score: 0.528)
# 2. How to Defeat Jet Lag, Shift Work & Sleeplessness
# (Score: 0.518)
# 3. Use Sleep to Enhance Learning, Memory & Emotional State | Dr. Gina Poe
# (Score: 0.486)
# 4. Dr. Matt Walker: Protocols to Improve Your Sleep | Huberman Lab Guest Series
# (Score: 0.47)
# 'on the Huberman Lab Podcast.'

# %%
results
# Out:
# [Document {'id': 'doc:43', 'payload': None, 'vector_score': '0.466051518917', 'title': 'Timing Light, Food, & Exercise for Better Sleep, Energy & Mood | Dr. Samer Hattar', 'text': "does post from time to time,\nmostly pictures of food\nthat is incredibly spicy,\nbut also information about chronobiology.\nHe comes on for an\nInstagram Live every once\nin a while with me.\nSo, definitely give him a\nfollow there and on Twitter.\nAnd I'm sure that he'll be\nhappy to answer questions\nand entertain any and all\ndiscussions about chronobiology.\n- Absolutely, yeah.\nAnd light, yeah.\n- Great, thank you, Samer.\n- Awesome, thank you, Andrew.\n- Thank you for joining\nme for my conversation\nwith Dr. Samer Hattar.\nI hope you found it as interesting\nand informative as I did.\nIf you're enjoying this podcast\nand/or learning from it,\nplease subscribe to our YouTube channel.\nIn addition, please leave\nus comments and feedback\nin the comments section on YouTube.\nA great thing to do there\nwould be to make suggestions\nabout future topics you'd like us to cover\nor future guests you'd like me to host\non the Huberman Lab Podcast.\nIn addition, please\nsubscribe to our podcast\non Apple and Spotify.\nAnd on Apple, you can leave\nus up to a five star review.\nPlease also check out the\nsponsors that we mentioned\nat the beginning of the podcast.\nThat's a terrific way to support us.\nAnd we have a Patreon, it's\npatreon.com/andrewhuberman.\nAnd there you can support the podcast\nat any level that you like.\nFor those of you that are interested\nin supporting scientific research,\nyou can support the research\nin my laboratory on stress,\non sleep, and human performance\nand other related topics,\nby going to\nHubermanLab.stanford.edu/giving.\nAnd there you can make a\ntax deductible donation\nat any level that you like.\nIf you're not already\nfollowing us on Instagram,\nplease follow us @HubermanLab on Instagram\nand also on Twitter.\nBoth those places I teach neuroscience\nand offer information\nthat's not always covered\non the Huberman Lab Podcast.\nAnd last, but certainly not least,\nthank you for your interest in science.\n[light music]", 'chunk_key': 'oUu3f0ETMJQ_chunk_32'},
#  Document {'id': 'doc:2', 'payload': None, 'vector_score': '0.472487807274', 'title': 'Master Your Sleep & Be More Alert When Awake', 'text': "A note about sleepwalkers and\npeople with very vivid dreams,\ntheanine can often make\nyour dreams very vivid,\nsleepwalkers should be\ncareful about taking theanine,\neveryone should be careful\nabout taking anything,\nand don't take anything\nwithout consulting your\nboard-certified M.D.\nor healthcare professional first, okay?\nYour health is your responsibility,\nI am not gonna take responsibility\nfor what you decide to do\nexperimentally in any case,\nbut especially as it relates\nto supplementation and drugs.\nAs a important point, apigenin\nis a fairly potent estrogen inhibitor,\nso women who want to keep\ntheir estrogen levels high,\nor at whatever levels\nthey happen to be at,\nshould probably avoid apigenin altogether,\nand men, take that into\nconsideration as well,\nmen need estrogen also,\nyou don't wanna completely\neliminate your estrogen,\nthat it can create all\nsorts of bad effects\non libido and cognition, et cetera,\nso apigenin in some people\nis gonna be a pretty\nstrong estrogen inhibitor,\nso keep that in mind.\nThere are other things you can take\nto help you sleep better,\nthose are the legal ones\nthat, at least I'm aware of,\nhave pretty broad safety margins,\nbut again, you need to explore\nyour safety margins with any compound.\nI think a great website\nthat I can refer you to is examine.com,\nexamine, the word, just as it\nsounds, .com, is a website,\nI have no relation to them,\nbut there, you can find links\nto peer-reviewed studies\nfor any compound or supplement,\nas well as some important warnings\nrelated to the things I discussed,\nas well as any other thing\nthat you might decide to supplement with\nor ingest to help improve your sleep.\nOkay, that was a lot of information\nabout how to get better at sleeping,\nfalling asleep, wakefulness, et cetera.\nAn important feature of\nthis podcast, as you know,\nis that we dive deep into topics\nfor several episodes at a time,\nat least a month at a time,\nso by stopping here, I recognize\nthat there are probably\nmany more questions\nthat you still have,\nand the great thing about that\nis that we have another\nepisode coming up soon,\nI'm going to hold office hours\nwhere I'm going to answer\nyour specific questions\nabout episodes one and two,\nso if you have questions\nabout this episode,\nyou have questions about episode one,\nwrite them down, put them in the comments,\nI'll also do a post on Instagram\nwhere you can put them\nin the comments there,\nbut put them in the comments\nto this episode as well,\nplease recommend the\npodcast if you like it,\nplease subscribe to it here on YouTube,\nplease subscribe to it on Apple,\nwe're now on Spotify as well,\nrecommend it to a friend,\nthe community that we're creating here\naround these topics of\nsleep and wakefulness\nand other neuroscience-\nand health-related themes\nis best supported by your\ninvolvement and your questions,\nand so I'm going to be\nreading all of your questions,\ndistilling those into the\nmost commonly asked questions\nand liked questions,\nso if you see something below\nthat you are particularly interested in,\nyou don't have to put\nthat question in again,\nyou can just give it a like,\nthe little thumbs-up tab,\nand if you're listening to\nthis on Spotify or Apple,\nplease go to YouTube, subscribe,\nand put your question there,\nor check out the Huberman Lab Instagram\nand you can put your questions there\nso that next episode, I\ncan answer those questions\nand then we can move forward\neven more deeply into\nthese critical topics\naround sleep and wakefulness\nso that you can be armed\nwith all the information\nand resources that you need.\nLast but not least, a number of you\nhave very graciously asked how\nyou can support the podcast,\nthe best way to support the podcast\nis to subscribe on YouTube or\none of the other plat ...
#  Document {'id': 'doc:4', 'payload': None, 'vector_score': '0.481831789017', 'title': 'How to Defeat Jet Lag, Shift Work & Sleeplessness', 'text': "So up until now I've been reluctant\nto recommend specific supplement brands.\nThe supplement industry\nis kind of a wild west\nof different brands,\ndifferent levels of\nquality and stringency.\nIt can be very complicated\nand what's on the bottle is\nnot always what you're getting.\nThe quality of what you're getting\nvaries from company to company,\nand even from substance to\nsubstance, batch to batch.\nSo I'm pleased to say that\nI'm partnering with Thorne,\nThorne, spelled T-H-O-R-N-E,\nis a supplement company that\nworks with the Mayo Clinic,\nand with pretty much all the\nmajor sports team organizations\nand that I know to have the\nhighest levels of stringency\nin terms of what's in the bottle\nmatches what's listed on the bottle,\nand in terms of the quality\nof what they put in those supplements.\nSo, while I mentioned earlier,\nthat supplements aren't for everybody.\nIf you're interested in trying\nsome of these supplements\nyou might want to check out Thorne.\nIf you want to do that you can go to\nthorne.com/u/huberman.\nSo it's t-h-o-r-n-e.com,\nc-o-m slash the letter u slash huberman,\nand if you do that,\nthey'll give you 20% off\nany of the supplements\nthat you happen to purchase from Thorne.\nThanks so much for your\ntime and attention.\nI really appreciate it.\nSee you next time on the\nHuberman Lab Podcast.\nAnd as always, thanks for\nyour interest in science.\n[bright music]", 'chunk_key': 'NAATB55oxeQ_chunk_24'},
#  Document {'id': 'doc:115', 'payload': None, 'vector_score': '0.513508856297', 'title': 'Use Sleep to Enhance Learning, Memory & Emotional State | Dr. Gina Poe', 'text': "GINA POE: Yes.\nANDREW HUBERMAN: We need them.\nAnd they need to have\na standard of living.\nI'm not afraid to say that\ndespite my primary employer.\nPay them more.\nThey need it.\nThey deserve it.\nGINA POE: They deserve\nit, absolutely.\nANDREW HUBERMAN: Great.\nWell, we will absolutely\nhave you back again\nif you'll be willing.\nAnd meanwhile, we\nwill direct people\nto where they can\nlearn more about you\nand your exciting work.\nAnd once again, thanks so much.\nGINA POE: Thank you so much.\nANDREW HUBERMAN: Thank\nyou for joining me today\nfor my discussion about sleep,\nmental health, physical health,\nand performance\nwith Dr. Gina Poe.\nI hope you found it to be as\ninformative and as actionable\nas I did.\nIn fact, I'm already\nimplementing the regularity\nof bedtime plus or\nminus half an hour\nin order to get that\ngrowth hormone release.\nAnd I can already see\nboth my sleep scores\nimproving and my\nfeelings of daytime vigor\nand focus and other markers of\nsleep health improving as well.\nIf you're learning from\nand/or enjoying this podcast,\nplease subscribe to\nour YouTube channel.\nThat's a terrific zero\ncost way to support us.\nIn addition, please\nsubscribe to the podcast\non both Spotify and Apple.\nAnd on both Spotify\nand Apple, you\ncan also leave us up\nto a five-star review.\nIf you have questions for us\nor comments or suggestions\nabout guests you'd like me\nto include on the podcast,\nplease put those in the\ncomments section on YouTube.\nI do read all the comments.\nIn addition, please\ncheck out the sponsors\nmentioned at the beginning and\nthroughout today's episode.\nThat's the best way to\nsupport this podcast.\nOn the Huberman Lab podcast,\nwe often discuss supplements.\nWhile supplements aren't\nnecessary for everybody,\nmany people derive tremendous\nbenefit from them for things\nlike enhancing the quality\nand duration of sleep,\nfor enhancing focus,\nand for hormone support.\nThe Huberman Lab podcast\nis proud to announce\nthat we've partnered with\nMomentous supplements.\nWe've done that for\nseveral reasons.\nFirst of all,\nMomentous supplements\nare of the very highest quality.\nSecond of all, they mainly\nfocus on single ingredient\nformulations which is\nabsolutely key if you\nwant to develop a\nsupplement regimen that's\nmost biologically\nand cost effective.\nIt, for instance, allows you to\nalternate dosages across days\nto change the dosages of\nindividual ingredients,\nso on and so forth.\nIn addition,\nMomentous supplements\nship internationally,\nwhich we know\nis important because many of\nyou reside outside of the United\nStates.\nIf you'd like to see the\nsupplements discussed\non the Huberman Lab podcast,\nplease go to livmomentous,\nspelled o-u-s, so that's\nlivmomentous.com/huberman.\nYou can get a 20% discount\non any of those supplements.\nAgain, it's a\nlivmomentous.com/huberman.\nThe Huberman Lab podcast\nhas a zero cost newsletter\nthat includes summaries of\npodcast episodes and toolkits,\nso checklist of\nactionable tools that you\ncan use for all aspects of\nmental health, physical health,\nand performance.\nYou can access this\ncompletely zero cost\nby going to hubermanlab.com,\ngo to the menu,\nand scroll down to newsletter.\nJust put in your email.\nWe do not share your\nemail with anybody.\nAnd you will get our\nmonthly newsletter\nand there are also some\nexamples of previous newsletters\nalso there at hubermanlab.com.\nYou're not already following\nme on social media,\nit is Huberman Lab on all\nplatforms, Instagram, Twitter,\nFacebook, and LinkedIn.\nAnd at all of those\nplaces, I cover\nscience and science-related\ntools, some of which\noverlap with the content\nof the Huberman Lab podcast\nbut much of which is distinct\nfrom the Huberman Lab\npodcast content.\nAgain, that's Huberma ...
#  Document {'id': 'doc:193', 'payload': None, 'vector_score': '0.529652476311', 'title': 'Dr. Matt Walker: Protocols to Improve Your Sleep | Huberman Lab Guest Series', 'text': "guests that you'd like me to feature on\nthe hubman Lab podcast please put those\nin the comment section on YouTube I do\nread all the comments on many episodes\nof The hubman Lab podcast we discuss\nsupplements while supplements aren't\nnecessary for everybody many people\nderive tremendous benefit from them for\nthings like improving sleep for hormone\nsupport and for Focus to learn more\nabout the supplements discussed on the\nhubman loud podcast go to live momentus\nspelled o us that's Liv mous.com\nhuberman if you're not already following\nme on social media I'm hubman lab on all\nsocial media platforms so that's\nInstagram X LinkedIn Facebook and\nthreads and on all those platforms I\ndiscuss science and science related\ntools some of which overlaps with the\ncontent of the hubman Lab podcast but\nmuch of which is distinct from the\ncontent covered on the huberman Lab\npodcast so again it's hubman lab on all\nsocial media platforms if you haven't\nalready subscribed to our neural network\nnewsletter our neural network newsletter\nis a zeroc cost newsletter that provides\npodcast summaries as well as protocols\nin the form of brief 1 to three page PD\nf s that cover everything from\nneuroplasticity and learning to sleep to\ndeliberate cold exposure and deliberate\nheat exposure we have a foundational\nFitness protocol and much more all of\nwhich again is completely zero cost you\nsimply go to huberman lab.com go to the\nmenu tab scroll down to newsletter and\nby supplying your email you can\nsubscribe I want to point out that we do\nnot share your email with anybody thank\nyou once again for joining me for\ntoday's discussion all about sleep with\nDr Matthew Walker and last but certainly\nnot least thank you for your interest in\nsign that's\n[Music]", 'chunk_key': 'hvPGfcAgk9Y_chunk_31'}]
