# %% [markdown]
# # Enhance Optics with Database Chat

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import numpy as np
import pickle
from dotenv import load_dotenv
import os
from typing import List
import openai
import redis
from redis.commands.search.indexDefinition import (
    IndexDefinition,
    IndexType
)
from redis.commands.search.query import Query
from redis.commands.search.field import (
    TextField,
    VectorField
)
from utils import process_query, search_redis, get_video_key, get_chunk_index

# %%
load_dotenv()
open_api_key = os.getenv("OPENAI_API_KEY")
openai_client = openai.OpenAI(api_key=open_api_key)

# %%
REDIS_HOST =  "localhost"
REDIS_PORT = 6379
REDIS_PASSWORD = "" # default for passwordless Redis

# Connect to Redis
redis_client = redis.Redis(
    host=REDIS_HOST,
    port=REDIS_PORT,
    password=REDIS_PASSWORD
)
redis_client.ping()
# Out:
# True

# %%
EMBEDDING_MODEL = "text-embedding-3-small"

# %%
search_redis(
    openai_client, 
    redis_client, 
    'Sleep and Exercise', 
    vector_field='content_vector', 
    k=10
)
# Out:
# [Document {'id': 'doc:240', 'payload': None, 'vector_score': '0.505926907063', 'title': 'How to Defeat Jet Lag, Shift Work & Sleeplessness | Huberman Lab Essentials', 'text': "increasing, get light.\nIt's that simple.\nI'm going to pause there.\nAnd then I want to talk\nabout kids and the elderly.\nIn other words,\nhow do we control\nsleep, and circadian\nrhythms, and wakefulness\nin babies, adolescents,\nteens, and aged folks?\nAll right.\nAs I mentioned earlier,\nmelatonin is not cyclic.\nIt's not cycling in babies.\nIt's more phasic.\nIt's being released\nat a constant level.\nAnd babies tend to be smaller\nthan adults, they are.\nAnd so those concentrations\nof melatonin are very high.\nAs a baby grows, those\nconcentrations per unit volume\nare going to go down.\nBabies are not born with a\ntypical sleep-wake cycle.\nAnd now, all the parents\nare saying, tell me\nsomething I didn't know.\nPerhaps, the most\nimportant thing,\nif you're having to map\nto a baby's schedule\nin orde
# ...

# %%
get_video_key('4b6bwcWK6GE_chunk_0')
# Out:
# '4b6bwcWK6GE'

# %%
user_query = "How do I become more productive?"

response = process_query(user_query)

# with open("chat_history/prompts/prompt_5.txt", "r", encoding="utf-8") as f:
#     instructions = f.read()

# response = openai_client.responses.create(
#     model="o4-mini",
#     instructions=instructions,
#     input=user_query,
# )

# %%
response
# Out:
# 'Here are six independent, science-backed approaches to boost productivity—each with its relative impact and “best-use” cases. Pick and combine the ones that fit your life and goals.\n\n1. Structure Work Around Your Biology  \n  • What: Carve your day into 90-minute “deep-work” blocks (first block upon waking), separated by 15- to 30-minute breaks or non-sleep deep rest (NSDR).  \n  • Why: We naturally cycle through ~90-minute ultradian rhythms of high focus and lower focus. Aligning work to the high-focus phase yields maximal cognitive throughput.  \n  • Relative Effectiveness: Very high. Can double or triple your hours of true “flow” compared to undirected work.  \n\n2. Optimize Your Circadian Rhythm  \n  • What: Wake and sleep at consistent times; get bright light exposure within 30 min of waking; dim lights after sunset. Avoid late-day caffeine.  \n  • Why: A stable circadian rhythm sharpens alertness daytime and consolidates deep sleep at night, reducing grogginess and midday cr
# ...
